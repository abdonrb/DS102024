# %% [markdown]
# # Pokemon **

# %% [markdown]
# ### Step 1. Importa las librerías necesarias

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Activa matplotlib de forma estática

# %%
# %matplotlib inline

# %% [markdown]
# ### Step 3. Lee 'pokemon.csv' de esta [url](https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv), lee la primera columna del csv como índice del DataFrame

# %%
pokemon = pd.read_csv('https://gist.githubusercontent.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6/raw/92200bc0a673d5ce2110aaad4544ed6c4010f687/pokemon.csv')

# %%
df = pokemon.copy()

# %% [markdown]
# ### Step 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df = df.set_index('#')

# %% [markdown]
# ### Step 5. Haz un scatter plot con `lmplot()`, que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado `data`

# %%
sns.lmplot(x='Attack', y='Defense', data=df)
plt.show();

# %% [markdown]
# ### Step 6. No queremos ver la línea recta de la regresión lineal.
# Prueba a añadir fit_reg a falso

# %%
sns.lmplot(x='Attack', y='Defense', data=df,fit_reg=False)
plt.show();

# %% [markdown]
# ### Step 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el `hue` sea el Stage

# %%
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 1         65       65     45           1      False
# 2         80       80     60           1      False
# 3        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 719      100      150     50           6       True
# 719      160      110    110           6       True
# 720      150      130     70           6       True
# 720      170      130     80           6       True
# 721      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
sns.lmplot(x='Attack',
            y='Defense', 
            data=df,
            fit_reg=False,
            hue='Generation')
plt.show();

# %% [markdown]
# ### Step 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(x='Attack',
            y='Defense', 
            data=df,
            fit_reg=False,
            hue='Generation')

plt.xlim(20,100)
plt.show();

# %% [markdown]
# ### Step 9. Dibuja un diagrama de cajas con el dataframe

# %%
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(10, 6))
sns.boxplot(numeric_df)
# Out:
# <Axes: >

# %% [markdown]
# ### Step 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
df = df.drop(columns=['Total','Legendary'])

# %%
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(10, 6))
sns.boxplot(numeric_df)
# Out:
# <Axes: >

# %% [markdown]
# ### Step 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### Step 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
type1 = df[(df['Type 1'] == 'Grass') |( df['Type 1'] == 'Fire')| (df['Type 1'] == 'Water')]

# %% [markdown]
# ### Step 13. Usa un estilo 'whitegrid'

# %%
sns.set_style("whitegrid")

# %% [markdown]
# ### Step 14. Pinta diagramas de violín con el DataFrame

# %%
sns.violinplot(x='Type 1', y='Attack', data=type1)
# Out:
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %% [markdown]
# ### Step 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
colores = ['#78C850', '#F08030',  '#6890F0']

# %% [markdown]
# ### Step 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(x='Type 1', y='Attack', data=type1,hue='Type 1',palette=colores);

# %% [markdown]
# ### Step 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# - Para ver esto, usamos el swarmplot.
# - Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.swarmplot(x='Type 1', y='Attack', data=type1,hue='Type 1',palette=colores);

# %% [markdown]
# ### Step 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos.
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(
    x='Type 1', 
    y='Attack', 
    data=type1, 
    inner=None,
    alpha=0.9
)

sns.swarmplot(
    x='Type 1', 
    y='Attack', 
    data=type1,
    alpha=0.8
)
plt.show();

# %% [markdown]
# ### Step 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
#  Dado un DataFrame, [melt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html) recibe varios parámetros:
#  * qué columnas del DataFrame se quedan igual
#  * qué nombres de columnas del dataframe pasan a ser una columna nueva
#  * cómo queremos llamar esas nuevas columnas
#
# Primero recuerda el Dataframe `df_grass_fire_water` con las primeras 5 filas

# %%
type1
# Out:
#                       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur  Grass  Poison   45      49       49       65
# 2                  Ivysaur  Grass  Poison   60      62       63       80
# 3                 Venusaur  Grass  Poison   80      82       83      100
# 3    VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4               Charmander   Fire     NaN   39      52       43       60
# ..                     ...    ...     ...  ...     ...      ...      ...
# 672                 Skiddo  Grass     NaN   66      65       48       62
# 673                 Gogoat  Grass     NaN  123     100       62       97
# 692              Clauncher  Water     NaN   50      53       62       58
# 693              Clawitzer  Water     NaN   71      73       88      120
# 721              Volcanion   Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation
# #
# 1         65     45           1
# 2         80     60           1
# 3        100     80           1
# 3        120     80           1
# 4         50     65           1
# ..       ...    ...         ...
# 672       57     52           6
# 673       81     68           6
# 692       63     44           6
# 693       89     59           6
# 721       90     70           6
#
# [234 rows x 10 columns]

# %% [markdown]
# ### Step 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
#
# Escribimos `df_grass_fire_water.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')`

# %%
df_melted = pd.melt(
    df, 
    id_vars=['Name', 'Type 1'],
    var_name='Nueva columna',
    value_name='Valor'
)

# %% [markdown]
# ### Step 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
df_melted
# Out:
#                        Name   Type 1 Nueva columna   Valor
# 0                 Bulbasaur    Grass        Type 2  Poison
# 1                   Ivysaur    Grass        Type 2  Poison
# 2                  Venusaur    Grass        Type 2  Poison
# 3     VenusaurMega Venusaur    Grass        Type 2  Poison
# 4                Charmander     Fire        Type 2     NaN
# ...                     ...      ...           ...     ...
# 6395                Diancie     Rock    Generation       6
# 6396    DiancieMega Diancie     Rock    Generation       6
# 6397    HoopaHoopa Confined  Psychic    Generation       6
# 6398     HoopaHoopa Unbound  Psychic    Generation       6
# 6399              Volcanion     Fire    Generation       6
#
# [6400 rows x 4 columns]

# %%
sns.swarmplot(x='Type 1', data=df_melted,hue='Type 1',palette=colores);
# Out:
# C:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\Temp\ipykernel_15744\3724953029.py:1: UserWarning:
# The palette list has fewer values (3) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.swarmplot(x='Type 1', data=df_melted,hue='Type 1',palette=colores);
# c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 22.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Error in callback <function _draw_all_if_interactive at 0x00000210BEF3AA20> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\backends\backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:566, in _CategoricalPlotter.plot_swarms.<locals>.draw(points, renderer, center)
#     564 def draw(points, renderer, *, center=center):
# --> 566     beeswarm(points, center)
#     568     if self.orient == "y":
#     569         scalex = False
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:3263, in Beeswarm.__call__(self, points, center)
#    3261 # Adjust points along the categorical axis to prevent overlaps
#    3262 new_xyr = np.empty_like(orig_xyr)
# -> 3263 new_xyr[sorter] = self.beeswarm(orig_xyr)
#    3265 # Transform the point coordinates back to data coordinates
#    3266 if self.orient == "y":
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:3307, in Beeswarm.beeswarm(self, orig_xyr)
#    3305 # Sort candidates by their centrality
#    3306 offsets = np.abs(candidates[:, 0] - midline)
# -> 3307 candidates = candidates[np.argsort(offsets)]
#    3309 # Find the first candidate that does not overlap any neighbors
#    3310 new_xyr_i = self.first_non_overlapping_candidate(candidates, neighbors)
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\numpy\_core\fromnumeric.py:1260, in argsort(a, axis, kind, order, stable)
#    1144 @array_function_dispatch(_argsort_dispatcher)
#    1145 def argsort(a, axis=-1, kind=None, order=None, *, stable=None):
#    1146     """
#    1147     Returns the indices that would sort an array.
#    1148
#    (...)
#    1258
#    1259     """
# -> 1260     return _wrapfunc(
#    1261         a, 'argsort', axis=axis, kind=kind, order=order, stable=stable
#    1262     )
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\numpy\_core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:
# c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 88.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Error in callback <function flush_figures at 0x00000210E0F93D80> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\IPython\core\display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\IPython\core\formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\IPython\core\formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\IPython\core\formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\backends\backend_agg.py:496, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     449 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     450     """
#     451     Write the figure to a PNG file.
#     452
#    (...)
#     494         *metadata*, including the default 'Software' key.
#     495     """
# --> 496     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\backends\backend_agg.py:444, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     439 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     440     """
#     441     Draw the canvas, then save it using `.image.imsave` (to which
#     442     *pil_kwargs* and *metadata* are forwarded).
#     443     """
# --> 444     FigureCanvasAgg.draw(self)
#     445     mpl.image.imsave(
#     446         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     447         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\backends\backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:566, in _CategoricalPlotter.plot_swarms.<locals>.draw(points, renderer, center)
#     564 def draw(points, renderer, *, center=center):
# --> 566     beeswarm(points, center)
#     568     if self.orient == "y":
#     569         scalex = False
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:3263, in Beeswarm.__call__(self, points, center)
#    3261 # Adjust points along the categorical axis to prevent overlaps
#    3262 new_xyr = np.empty_like(orig_xyr)
# -> 3263 new_xyr[sorter] = self.beeswarm(orig_xyr)
#    3265 # Transform the point coordinates back to data coordinates
#    3266 if self.orient == "y":
#
# File c:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\pypoetry\Cache\virtualenvs\bootcamp-ds-Zopo5587-py3.12\Lib\site-packages\seaborn\categorical.py:3306, in Beeswarm.beeswarm(self, orig_xyr)
#    3303 candidates = self.position_candidates(xyr_i, neighbors)
#    3305 # Sort candidates by their centrality
# -> 3306 offsets = np.abs(candidates[:, 0] - midline)
#    3307 candidates = candidates[np.argsort(offsets)]
#    3309 # Find the first candidate that does not overlap any neighbors
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon
#
# Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# Usando plt:
#   - fija el límite del eje Y entre 0 y 200
#   - fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %% [markdown]
# ### Step 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
#
# Las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
co = df[['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']].corr()
sns.heatmap(co, annot=True)
plt.title("Mapa de Calor de Correlaciones")
plt.show()

# %% [markdown]
# ### Step 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
plt.figure(figsize=(10, 6))
sns.histplot(
    pokemon['Defense'], 
    kde=True,
    color='skyblue',
    bins=20, 
    alpha=0.8
);

# %% [markdown]
# ### Step 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot y plt.xticks para girar las etiquetas

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Type 1',hue='Type 1',palette=colores)
plt.xticks(rotation=45);
# Out:
# C:\Users\Abdon.RAMIREZ-BRICEN\AppData\Local\Temp\ipykernel_15744\3500310554.py:2: UserWarning:
# The palette list has fewer values (3) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(data=df, x='Type 1',hue='Type 1',palette=colores)

# %% [markdown]
# ### Step 26. Usa catplot con el DataFrame original.
# Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendariosy divide los colores según el Type 2

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendariosy divide los colores según el Type 2

# %%
pokemon['Legendary'] = pokemon['Legendary'].astype(bool)

fig, axes = plt.subplots(1, 2, figsize=(15, 6), sharey=True)

sns.stripplot(ax=axes[0], x='Type 1', y='Defense', hue='Type 2', data=pokemon[pokemon['Legendary'] == False], dodge=True,legend=False)
axes[0].set_title('Legendary = False')
axes[0].tick_params(axis='x', rotation=45)
axes[0].set_xlabel('Type 1')
axes[0].set_ylabel('Defense')

sns.stripplot(ax=axes[1], x='Type 1', y='Defense', hue='Type 2', data=pokemon[pokemon['Legendary'] == True], dodge=True)
axes[1].set_title('Legendary = True')
axes[1].tick_params(axis='x', rotation=45)
axes[1].set_xlabel('Type 1')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# ### Step 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.

# %%
sns.kdeplot(x='Attack',y='Defense',data=pokemon);

# %% [markdown]
# ### Step 29. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original

# %%
g = sns.jointplot(x="Attack", y="Defense", data=pokemon, kind="scatter")

g.ax_joint.set_xlim(0, 140)
g.ax_joint.set_ylim(0, 180)

g.ax_joint.set_xlabel('Attack')
g.ax_joint.set_ylabel('Defense')
plt.show()
