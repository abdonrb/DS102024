# %%
import pandas as pd

# %%
df = pd.read_csv('data/winequality-red.csv', sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
import seaborn as sns

# %%
# sns.pairplot(df)

# %%
import numpy as np

# %%
# np.log(y).plot(kind='hist')

# %%
# np.log(y).mode()

# %%
# np.log(y).describe()

# %%
X = df.drop(columns='alcohol')
y = np.log(df['alcohol'])

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PowerTransformer

esc = StandardScaler()

esc.fit(X)

X_esc = esc.transform(X)

# %%
X = X_esc

# %%
# sns.heatmap(np.where(np.abs(X.corr())>0.5,X.corr(),0),annot=True,cmap='Reds')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_percentage_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=69)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

print('RMSE:', root_mean_squared_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# RMSE: 0.05994792887068336
# R2: 0.6414908626950996
# MAPE: 0.0201479960763013

# %%
dct = {'C':[],
       'Kernel':[],
       'RMSE':[],
       'r2_score':[],
       'MAPE':[]}

for i in range(1,100,1):
    for j in [1,2,3,4,5]:
        svr = SVR(C=i/100,kernel='poly',degree=j)
        svr.fit(X_train, y_train)

        y_pred = svr.predict(X_test)

        dct['C'].append(i)
        dct['Kernel'].append(j)
        dct['RMSE'].append(root_mean_squared_error(y_test, y_pred))
        dct['r2_score'].append(r2_score(y_test, y_pred))
        dct['MAPE'].append(mean_absolute_percentage_error(y_test, y_pred))

pd.DataFrame(dct).sort_values('MAPE',ascending=True)
# Out:
#       C  Kernel      RMSE   r2_score      MAPE
# 400  81       1  0.060452   0.635434  0.021443
# 480  97       1  0.060441   0.635570  0.021443
# 465  94       1  0.060446   0.635505  0.021446
# 435  88       1  0.060451   0.635450  0.021451
# 455  92       1  0.060455   0.635405  0.021451
# ..   ..     ...       ...        ...       ...
# 379  76       5  0.390702 -14.227991  0.050227
# 394  79       5  0.389387 -14.125644  0.050228
# 389  78       5  0.389797 -14.157515  0.050229
# 374  75       5  0.391377 -14.280671  0.050232
# 399  80       5  0.389499 -14.134408  0.050247
#
# [495 rows x 5 columns]

# %%
# baseline
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

lr = LinearRegression()
svr = SVR()
knn = KNeighborsRegressor()

from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
param_grid = {'C':[0.0001,0.001,0.01,0.1,1,10,100,100],
              'kernel':['linear','poly','rbf','sigmoid'],
              'gamma':[1,0.1,0.001,0.0001]}

grid_search = RandomizedSearchCV(SVR(),param_grid,cv=5,n_iter=128,n_jobs=-1)

grid_search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVR(), n_iter=128, n_jobs=-1,
#                    param_distributions={'C': [0.0001, 0.001, 0.01, 0.1, 1, 10,
#                                               100, 100],
#                                         'gamma': [1, 0.1, 0.001, 0.0001],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
print('RMSE:', root_mean_squared_error(y_test, y_pred))
print('R2:', r2_score(y_test, y_pred))
print('MAPE:', mean_absolute_percentage_error(y_test, y_pred))

# %%
pd.DataFrame(X).describe()
# Out:
#                  0             1             2             3             4   \
# count  1.599000e+03  1.599000e+03  1.599000e+03  1.599000e+03  1.599000e+03
# mean   3.554936e-16  1.733031e-16 -8.887339e-17 -1.244227e-16  3.732682e-16
# std    1.000313e+00  1.000313e+00  1.000313e+00  1.000313e+00  1.000313e+00
# min   -2.137045e+00 -2.278280e+00 -1.391472e+00 -1.162696e+00 -1.603945e+00
# 25%   -7.007187e-01 -7.699311e-01 -9.293181e-01 -4.532184e-01 -3.712290e-01
# 50%   -2.410944e-01 -4.368911e-02 -5.636026e-02 -2.403750e-01 -1.799455e-01
# 75%    5.057952e-01  6.266881e-01  7.652471e-01  4.341614e-02  5.384542e-02
# max    4.355149e+00  5.877976e+00  3.743574e+00  9.195681e+00  1.112703e+01
#
#                  5             6             7             8             9   \
# count  1.599000e+03  1.599000e+03  1.599000e+03  1.599000e+03  1.599000e+03
# mean  -6.221137e-17  4.443669e-17 -3.473172e-14  2.861723e-15  6.754377e-16
# std    1.000313e+00  1.000313e+00  1.000313e+00  1.000313e+00  1.000313e+00
# min   -1.422500e+00 -1.230584e+00 -3.538731e+00 -3.700401e+00 -1.936507e+00
# 25%   -8.487156e-01 -7.440403e-01 -6.077557e-01 -6.551405e-01 -6.382196e-01
# 50%   -1.793002e-01 -2.574968e-01  1.760083e-03 -7.212705e-03 -2.251281e-01
# 75%    4.901152e-01  4.723184e-01  5.768249e-01  5.759223e-01  4.240158e-01
# max    5.367284e+00  7.375154e+00  3.680055e+00  4.528282e+00  7.918677e+00
#
#                  10
# count  1.599000e+03
# mean   8.887339e-17
# std    1.000313e+00
# min   -3.265165e+00
# 25%   -7.878226e-01
# 50%    4.508484e-01
# 75%    4.508484e-01
# max    2.928190e+00

# %%
lr.coef_
# Out:
# array([ 0.07868717,  0.00877388,  0.01526229,  0.03545866, -0.00548689,
#        -0.00130888, -0.00655553, -0.09966425,  0.05192412,  0.0140415 ,
#         0.01690194])

# %%
X
# Out:
# array([[-0.52835961,  0.96187667, -1.39147228, ...,  1.28864292,
#         -0.57920652, -0.78782264],
#        [-0.29854743,  1.96744245, -1.39147228, ..., -0.7199333 ,
#          0.1289504 , -0.78782264],
#        [-0.29854743,  1.29706527, -1.18607043, ..., -0.33117661,
#         -0.04808883, -0.78782264],
#        ...,
#        [-1.1603431 , -0.09955388, -0.72391627, ...,  0.70550789,
#          0.54204194,  0.45084835],
#        [-1.39015528,  0.65462046, -0.77526673, ...,  1.6773996 ,
#          0.30598963, -0.78782264],
#        [-1.33270223, -1.21684919,  1.02199944, ...,  0.51112954,
#          0.01092425,  0.45084835]])

# %%
pd.DataFrame(lr.coef_.reshape(1,-1),columns=X.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 pd.DataFrame(lr.coef_.reshape(1,-1),columns=X.columns)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
lr.intercept_
# Out:
# np.float64(53.238770193909644)

# %% [markdown]
# ----------

# %% [markdown]
# # Clase para regresión lineal

# %%
import numpy as np
import pandas as pd

class LinearRegressionBootcamp:
    def __init__(self, normalized=False):
        self.coeficientes = None
        self.intercepto = None
        self.media = None
        self.desviacion_estandar = None
        self.normalized = normalized

    def _normalizado_features(self, X:pd.DataFrame):
        if self.media is None or self.desviacion_estandar is None:
            self.media = X.mean(axis=0)
            self.desviacion_estandar = X.std(axis=0)

        return (X - self.media) / self.desviacion_estandar

    def fit(self, df:pd.DataFrame, target:str):
        X = df.drop(columns=target)
        self.feature_columns = X.columns
        y = df[target].values

        if self.normalized:
            X = self._normalizado_features(X)

        X = np.c_[np.ones(X.shape[0]), X]

        theta = np.linalg.solve(X.T @ X, X.T @ y)

        self.intercepto = theta[0]
        self.coeficientes = theta[1:]  # Corregido: los coeficientes son desde el índice 1

    def predict(self, df: pd.DataFrame):
        if self.coeficientes is None or self.intercepto is None:
            raise ValueError('El modelo no ha sido entrenado.')

        X = df[self.feature_columns].copy()

        if self.normalized:
            X = self._normalizado_features(X)

        X = X.values  # Convertimos a numpy array después de normalizar

        y_pred = self.intercepto + np.dot(X, self.coeficientes)

        return y_pred

# %%
model = LinearRegressionBootcamp(normalized=True)

model.fit(df, 'alcohol')

print('Intercepto:', model.intercepto)
print('Coeficientes:', model.coeficientes)

y_pred = model.predict(df)

print('RMSE:', root_mean_squared_error(df['alcohol'].values, y_pred))
print('R2:', r2_score(df['alcohol'].values, y_pred))
print('MAPE:', mean_absolute_percentage_error(df['alcohol'].values, y_pred))
# Out:
# Intercepto: 10.422983114446494
# Coeficientes: [ 0.85745535  0.10552457  0.15968768  0.36993179 -0.04390991 -0.03157529
#  -0.04573902 -1.08263909  0.55842251  0.1617152   0.18753436]
# RMSE: 0.5919529738606677
# R2: 0.6912531089251452
# MAPE: 0.043295300438974574
